# %%
import pandas as pd 
from matplotlib import pyplot as plt

# %%
rt = 'data/data.csv'

# %%
df = pd.read_csv(rt)
df
# Out:
#           time  0_requests      0_cpu    0_pods    0_cost  0_memory  \
# 0            0   -0.655446  -1.360354 -2.865182  0.889922 -4.952502
# 1           60   -0.655446  -1.360354 -2.865182  1.074922 -3.364304
# 2          120   -0.655446  27.017466 -2.865182  0.963922 -3.801133
# 3          180   -0.655446   6.073777 -2.865182  0.882922 -4.460846
# 4          240   -0.655422   5.230597 -2.615313  0.868297 -3.505022
# ...        ...         ...        ...       ...       ...       ...
# 44635  2678100   -0.655436  -1.360354 -2.740247  0.080422  1.357232
# 44636  2678160   -0.655446  -1.360354 -2.865182  0.008922  6.421140
# 44637  2678220   -0.655415   0.586572 -2.573668  0.042122  1.623054
# 44638  2678280   -0.655439  -1.360354 -2.781892  0.076256  2.889759
# 44639  2678340   -0.655432  -0.827548 -2.740247  0.038522  4.266316
#
#        1_requests     1_cpu    1_pods    1_cost  ...  46_requests    46_cpu  \
# ...
